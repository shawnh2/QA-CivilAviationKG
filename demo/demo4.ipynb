# %%
import os

os.chdir(os.path.join(os.getcwd(), '..'))

from chatbot import CAChatBot

chatbot = CAChatBot(mode='notebook')
# Out:
# 欢迎与小航对话，请问有什么可以帮助您的？

# %% [markdown]
# ### 在这个demo中，你将看到如下几个问题类型的回答和介绍：
# 1. index_compose
# 2. indexes_trend
# 3. areas_trend
# 4. indexes_overall_trend
# 5. areas_overall_trend
# 6. indexes_change
# 7. catalogs_change
# 8. indexes_max

# %% [markdown]
# ## 1. index_compose
# 以图表的方式回答了某一个年度某项（一或多个）指标的子指标的构成情况。

# %%
ans, chart = chatbot.query('2013年运输总周转量的子集有？')
print(ans)
chart.render_notebook()
# Out:
# 该问题的回答已渲染为图像，详见：results/qa-cakg-2013年运输总周转量的子集有？.html。
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="338d46d5deac4d009903ac7d4df92886" style="width:auto; height:300px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_338d46d5deac4d009903ac7d4df92886 = echarts.init(
#                     document.getElementById('338d46d5deac4d009903ac7d4df92886'), 'white', {renderer: 'canvas'});
#                 var option_338d46d5deac4d009903ac7d4df92886 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
ans, chart = chatbot.query('2011年航空公司计划航班的组成？')
print(ans)
chart.render_notebook()
# Out:
# 该问题的回答已渲染为图像，详见：results/qa-cakg-2011年航空公司计划航班的组成？.html。
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d3f72a9565834758b8bd9a8485e39699" style="width:auto; height:300px;"></div>
#         <div id="f4ac2f95ed544d2384a0861e34624b1d" style="width:auto; height:300px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d3f72a9565834758b8bd9a8485e39699 = echarts.init(
#                     document.getElementById('d3f72a9565834758b8bd9a8485e39699'), 'white', {renderer: 'canvas'});
#                 var option_d3f72a9565834758b8bd9a8485e39699 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
# ...

# %%
ans, chart = chatbot.query('2011年指标停用机场的组成有哪些？')
print(ans)
# Out:
# 指标“停用机场”没有任何组成。

# %% [markdown]
# ## 2. indexes_trend
# 以图表的方式回答了某项指标在某段时间内的变化情况。

# %%
ans, chart = chatbot.query('2011-13年运输总周转量和旅客周转量情况？')
print(ans)
chart.render_notebook()
# Out:
# 该问题的回答已渲染为图像，详见：results/qa-cakg-2011-13年运输总周转量和旅客周转量情况？.html。
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1b5cb7c319bf476bb0418102f1eae262" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1b5cb7c319bf476bb0418102f1eae262 = echarts.init(
#                     document.getElementById('1b5cb7c319bf476bb0418102f1eae262'), 'light', {renderer: 'canvas'});
#                 var option_1b5cb7c319bf476bb0418102f1eae262 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
# ...

# %%
ans, chart = chatbot.query('2011-13年节能减排情况？')
print(ans)
# Out:
# 指标“节能减排”非数值类型，无法比较。

# %% [markdown]
# ## 3. areas_trend
# 以图表的方式回答了某个地区的某项指标在某段时间内的变化情况。

# %%
ans, chart = chatbot.query('2011-13年港澳台运输总周转量值分布状况？')
print(ans)
chart.render_notebook()
# Out:
# 该问题的回答已渲染为图像，详见：results/qa-cakg-2011-13年港澳台运输总周转量值分布状况？.html。
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="cb7c9bc0e410445a86f1a0ed045c52b1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_cb7c9bc0e410445a86f1a0ed045c52b1 = echarts.init(
#                     document.getElementById('cb7c9bc0e410445a86f1a0ed045c52b1'), 'light', {renderer: 'canvas'});
#                 var option_cb7c9bc0e410445a86f1a0ed045c52b1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
# ...

# %% [markdown]
# ## 4. indexes_overall_trend
# 以图表的方式回答了某项指标在某段时间内占总指标比例的变化情况。

# %%
ans, chart = chatbot.query('2011-13年货邮周转量和小型飞机平均日利用率占总体的比例的变化形势？')
print(ans)
chart.render_notebook()
# Out:
# 该问题的回答已渲染为图像，详见：results/qa-cakg-2011-13年货邮周转量和小型飞机平均日利用率占总体的比例的变化形势？.html。
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'macarons':'https://assets.pyecharts.org/assets/themes/macarons'
#         }
#     });
# </script>
#
#         <div id="c5794ef790ed4406a4288227163be299" style="width:900px; height:500px;"></div>
#         <div id="528537cd81214dc2a67055945d2d8f36" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'macarons'], function(echarts) {
#                 var chart_c5794ef790ed4406a4288227163be299 = echarts.init(
#                     document.getElementById('c5794ef790ed4406a4288227163be299'), 'macarons', {renderer: 'canvas'});
#                 var option_c5794ef790ed4406a4288227163be299 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
# ...

# %%
ans, chart = chatbot.query('2011-13年货邮周转量和货邮吞吐量占总体的比例的变化形势？')
print(ans)
chart.render_notebook()
# Out:
# 无关于”货邮吞吐量“的父级记录；该问题的回答已渲染为图像，详见：results/qa-cakg-2011-13年货邮周转量和货邮吞吐量占总体的比例的变化形势？.html。
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'macarons':'https://assets.pyecharts.org/assets/themes/macarons'
#         }
#     });
# </script>
#
#         <div id="1b7843fd468341558f1f892c0d9c5df1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'macarons'], function(echarts) {
#                 var chart_1b7843fd468341558f1f892c0d9c5df1 = echarts.init(
#                     document.getElementById('1b7843fd468341558f1f892c0d9c5df1'), 'macarons', {renderer: 'canvas'});
#                 var option_1b7843fd468341558f1f892c0d9c5df1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
# ...

# %% [markdown]
# ## 5. areas_overall_trend
# 以图表的方式回答了某个地区的某项指标在某段时间内占其总地区指标比例的变化情况

# %%
ans, chart = chatbot.query('2011-13年港澳台运输总周转量值占总比的分布状况？')
print(ans)
chart.render_notebook()
# Out:
# 该问题的回答已渲染为图像，详见：results/qa-cakg-2011-13年港澳台运输总周转量值占总比的分布状况？.html。
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'macarons':'https://assets.pyecharts.org/assets/themes/macarons'
#         }
#     });
# </script>
#
#         <div id="b1848c08b9444d63aa7591eda6b10a2b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'macarons'], function(echarts) {
#                 var chart_b1848c08b9444d63aa7591eda6b10a2b = echarts.init(
#                     document.getElementById('b1848c08b9444d63aa7591eda6b10a2b'), 'macarons', {renderer: 'canvas'});
#                 var option_b1848c08b9444d63aa7591eda6b10a2b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
# ...

# %%
ans, chart = chatbot.query('2011-13年国内运输总周转量占总体的比例的变化形势？')
print(ans)
# Out:
# 无关于”国内运输总周转量“的父级记录。

# %% [markdown]
# ## 6. indexes_change
# 以图表的方式回答了某段时间内指标个数的变化情况。

# %%
ans, chart = chatbot.query('2011-13年指标变化情况？')
print(ans)
chart.render_notebook()
# Out:
# 该问题的回答已渲染为图像，详见：results/qa-cakg-2011-13年指标变化情况？.html。
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ce32dcd9ef9c474496d3e744b72284a8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ce32dcd9ef9c474496d3e744b72284a8 = echarts.init(
#                     document.getElementById('ce32dcd9ef9c474496d3e744b72284a8'), 'white', {renderer: 'canvas'});
#                 var option_ce32dcd9ef9c474496d3e744b72284a8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %% [markdown]
# ## 7. catalogs_change
# 以图表的方式回答了某段时间内目录个数的变化情况。

# %%
ans, chart = chatbot.query('2011-13年目录变化情况？')
print(ans)
chart.render_notebook()
# Out:
# 该问题的回答已渲染为图像，详见：results/qa-cakg-2011-13年目录变化情况？.html。
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="cefa6ad7a4ea4fb99d029731cb2245d8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_cefa6ad7a4ea4fb99d029731cb2245d8 = echarts.init(
#                     document.getElementById('cefa6ad7a4ea4fb99d029731cb2245d8'), 'white', {renderer: 'canvas'});
#                 var option_cefa6ad7a4ea4fb99d029731cb2245d8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %% [markdown]
# ## 8. indexes_max
# 以图表的方式回答了某段时间内某项指标的最值（最大值与最小值）。

# %%
ans, chart = chatbot.query('2011-13年运输总周转量和货邮周转量最大值是？')
print(ans)
chart.render_notebook()
# Out:
# 该问题的回答已渲染为图像，详见：results/qa-cakg-2011-13年运输总周转量和货邮周转量最大值是？.html。
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f06bba6b98ee4f7b815f9a4f740a1c26" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f06bba6b98ee4f7b815f9a4f740a1c26 = echarts.init(
#                     document.getElementById('f06bba6b98ee4f7b815f9a4f740a1c26'), 'light', {renderer: 'canvas'});
#                 var option_f06bba6b98ee4f7b815f9a4f740a1c26 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
# ...

# %%
ans, chart = chatbot.query('2011-13年新增机场的最大值是？')
print(ans)
# Out:
# 指标“新增机场”非数值类型，无法比较。
